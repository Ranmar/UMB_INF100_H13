# %% [markdown]
# # INF100: Obligatorisk innlevering nr 5

# %% [markdown]
# ### Prinsipper ###
# 1. Dette er den femte av seks obligatoriske innleveringer i løpet av semesteret.
# 1. Hver innlevering vil bestå av tre oppgaver, i alt altså 18 oppgaver.
# 1. I tillegg kan det være mer krevende bonusoppgaver for deg som ønsker en utfordring. Bonusoppgavene krever kunnskap utover det som ble gjennomgått i forelesningene og skal stimulere deg til å lære deg mer om programmering på egenhånd. Godkjennte bonusoppgaver teller som vanlige oppgaver.
# 1. **Minst 12 oppgaver må være godkjent** for at du skal kunne gå opp til eksamen.
# 1. Innleveringen vil bli vurdert som den er når innleveringsfristen går ut. Du kan ikke levere om.
# 1. Å levere andres arbeid som ditt eget er fusk og vil bli anmeldt.
#
# ### Besvarelse og innlevering ###
# 1. Alle svar skal føres i denne Notebooken.
# 1. **Før du begynner, klikk på navnet på toppen av skjermen og endre den fra `INF100_H13_Oblig5` til `INF100_H13_Oblig5_Fornavn_Etternavn`, f eks `INF100_H13_Oblig5_Kari_Nordmann`**
# 1. **NB: Der er viktig at navnet til Notebooken din er bygget opp presist som vist ovenfor!**
# 1. Før navnet ditt og epostadressen din i feltene under!
# 1. Når du har besvart oppgavene, lagre Notebooken. Du vil da finne filen `INF100_H13_Oblig4_Fornavn_Etternavn.ipynb` i din Python mappe (evt kan du laste ned med `File > Download as > IPython`. Denne filen (og bare den) skal **lastes opp til oppgavesiden på Fronter** som besvarelse.
#
# ### Innleveringsfrist: Fredag, 15. november 2013, kl 12.00

# %% [markdown]
# ----------------
# ## Navn og epost ##
# Skriv inn navnet og epostadressen din i feltene under. **Uten dette vil du ikke få godskrevet innleveringen!**
#
# Navn og epostadressen skal settes i hermetegn, alstå
#
#     __author__ = "Kari Nordmann"
#     __epost__ = "kari.nordmann@student.umb.no"

# %%
__author__ = ""
__epost__ = ""

# %% [markdown]
# * * *
#
# ## Oppgave 13: Plotting
#
# I denne oppgaven skal du plotte funksjonene $\sin(x)$, $\sin(2x)$, $\sin(3x)$, $\sin(4x)$, og $\sin(5x)$ oppå hverandre i samme grafikk, med $0\leq x \leq 2\pi$, som i dette eksempel:

# %%
from IPython.display import Image ; Image(filename='Figures/o13_sines.png')

# %% [markdown]
# #### Føringer
# 1. Funksjonene skal plottes for $0 \leq x \leq 2\pi$.
# 1. Det skal brukes nok punkter langs $x$-aksen slik at alle kurvene er glatte i grafikken.
# 1. Du skal bruke en *løkke* for å plotte funksjonene, slik at din kode inneholder bare *ett* `plot()` kommando.

# %% [markdown]
# * * *
# ## Oppgave 14: Plotting ##
#
# Hittil har vi stort sett plottet funksjoner $f(x)$ som funksjon av $x$, f eks

# %%
x = linspace(0, 4*pi, num=200)
plot(x, sin(x))
plot(x, sin(2*x));
xlim(0, 4*pi);

# %% [markdown]
# Men vi kan ogå plotte en funksjon mot en annen funksjon, f eks ved å bruke $\sin(x)$ som x-verdier og $\sin(2x)$ som y-verdier. Dette kan det bli fine figurer av (grafikken viser et eksempel på en [Lissajous-figur](http://en.wikipedia.org/wiki/Lissajous_curve)):

# %%
plot(sin(x), sin(2*x));
xlim(-1.05, 1.05);
ylim(-1.05, 1.05);

# %% [markdown]
# I denne oppgaven skal du lage en pen grafikk som inneholder minst to kurver (i en grafikk) som tegnes ved å plotte en funskjon mot en annen, dvs en grafikk som inneholder minst to kurver laget på samme måte som figuren over. Du kan gjerne være kreativ og legge inn flere kurver!

# %%
# Skriv inn koden din her

# %% [markdown]
# * * *
# ## Oppgave 15: Tegn et mønster med `for` og `if`
#
# Du skal skrive Python-kode som lager det følgende diagrammet:
#
#     ***********
#     -*-*-*-*-*-
#     -*-*-*-*-*-
#     ***********
#     -*-*-*-*-*-
#     -*-*-*-*-*-
#     ***********
#     -*-*-*-*-*-
#     -*-*-*-*-*-
#     ***********
#
# Hver tredje linje er altså annerledes.
#
# #### Føringer
#
# 1. Koden din skal bestå av fem linjer.
# 2. Det skal være en `for`-løkke.
# 3. Det skal være en linje med `if` og en med `else`.
# 4. Det skal være to `print` kommandoer.
#
# For å se om `n` er delelig med tre, brukes `n % 3 == 0`. Her står `%` for "modulo", dvs for resten ved divisjon.

# %%
# Din kode kommer her (og denne linjene teller ikke med blant de 5 linjene)

# %% [markdown]
# * * *
# ## Bonusoppgave 5 ##
#
# I forelesningen har vi implementert biseksjonsmetoden ved hjelp av en `while`-løkke. Det er også mulig å implementere biseksjonsmetoden ved hjelp av rekursjon. Definer en funksjon `bisec_rec(a, b, epsilon)`, som bruker rekursjon for å implementere biseksjon. Forutsett av funksjonen vi skal finne nullposisjonen for heter `f`. Rekursjonen skal stoppe når `abs(f(x)) < epsilon`.

# %%
# Skriv inn koden din her
